# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[302,267,186,182,214,430,696]
y2=[440,800,900,924,1000,1377,1400]
y3=[464,703,790,1011,1135,1357,2036]
y4=[1510,1793,4699,7444,7887,9561,10099]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Arecanut')
plt.plot(x,y2,label='Arhar/Tur')
plt.plot(x,y3,label='Bajra')
plt.plot(x,y4,label='Banana')

ax.legend()

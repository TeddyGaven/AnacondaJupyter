# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[683.38,1595.8,6000,6791,6854.3,10681.98,10695.8]
y=[25870.9,3788,31863,20118,20539.6,29119.6,31600.8]
y2=[828.52,929,900,1011.8,366,1800,824.3]
y3=[6000,9503,12400,13825,14000,14500,14752]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andaman & Nicobar',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Rice')
plt.plot(x,y2,label='Dry Ginger')
plt.plot(x,y3,label='Samai')

ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[1061,1615,1745,1838,1970,1985,2111]
y2=[1136,1386,1542,1901,1911,2533,2610]
y3=[1251,1529,2142,2478,3052,3633,3410]
y4=[1200,1245,1615,2046,2140,2659,2924]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Beans & Mutter')
plt.plot(x,y2,label='Bhindi')
plt.plot(x,y3,label='Brinjal')
plt.plot(x,y4,label='Cabbage')

ax.legend()

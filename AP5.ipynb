# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[1244,1670,1526,1900,2239,2298,2667]
y2=[317,347,410,422,590,709,780]
y3=[1014,1104,1528,1720,1841,2042,2275]
y4=[719,740,842,1448,1518,1613,1642]
y5=[1012,1267,1354,1485,1621,1743,1944]
y6=[555,673,932,2048,2075,5644,7606]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Cotton(lint)')
plt.plot(x,y2,label='Cowpea(Lobia)')
plt.plot(x,y3,label='Dry Chillies')
plt.plot(x,y4,label='Dry Ginger')
plt.plot(x,y5,label='Gram')
plt.plot(x,y6,label='Grapes')

ax.legend()

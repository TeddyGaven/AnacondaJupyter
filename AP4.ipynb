# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[1335,1801,2512,2445,2996,3112,3438]
y2=[451,668,895,1035,1223,1313,2019]
y3=[1172,1918,2718,3418,3750,4000,4383]
y4=[900,1288,1559,1631,2124,2317,2477]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Cashewnut')
plt.plot(x,y2,label='Castor seed')
plt.plot(x,y3,label='Citrus Fruit')
plt.plot(x,y4,label='Coriander')

ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[73.33,53.5,67.5,71.3,145.26,128.02,268]
y2=[110,256,347,382,590,709,740]
y3=[546,673,932,2075,5644,6456,6886]
y4=[719,740,842,1448,1613,1642,1712]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Sugarcane')
plt.plot(x,y2,label='Cowpea')
plt.plot(x,y3,label='Grapes')
plt.plot(x,y4,label='Dry Ginger')

ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
x=[889.2,999.5,1400,1500,1560,2448.2,2879.52]
y=[1524,1568,1657,1700,1711,1720,1778]
y2=[790,800,882,1007,1149,1385,1412]
y3=[1221,1461,2000,2063,2410,3000,4251]
y4=[600,700,753,772,1000,1100,1263]
y5=[1725,1754,1833,1910,1926,1978,2147]
y6=[1000,1014,1021,1076,1125,1303,1401]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Andhra Pradesh',fontsize=30)
ax.set_xlabel('<---------Production---------->',fontsize=15)
ax.set_ylabel('<-------------Area------------->',fontsize=15)
plt.plot(x,y,label='Groundnut')
plt.plot(x,y2,label='Horse-gram')
plt.plot(x,y3,label='Jowar')
plt.plot(x,y4,label='Korra')
plt.plot(x,y5,label='Lemon')
plt.plot(x,y6,label='Maize')

ax.legend()
